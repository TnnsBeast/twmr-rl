# %% [markdown]
# # Demo
#
# I am recreating the important parts of the [dm_control_suite](https://github.com/google-deepmind/mujoco_playground/blob/main/learning/notebooks/dm_control_suite.ipynb) example.

# %%
import jax

from mujoco_playground import registry

# We must import twmr so that it registers itself with mujoco_playground
import twmr  # noqa: F401

# %%
env = registry.load("TransformableWheelMobileRobot")
env
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 env = registry.load("TransformableWheelMobileRobot")
#       2 env
#
# File /bigdata/rhome/ajcd2020/research/mujoco/Transformable-Leg-Wheel-Robot/.venv/lib64/python3.11/site-packages/mujoco_playground/_src/registry.py:59, in load(env_name, config, config_overrides)
#      57   return locomotion.load(env_name, config, config_overrides)
#      58 elif env_name in dm_control_suite.ALL_ENVS:
# ---> 59   return dm_control_suite.load(env_name, config, config_overrides)
#      61 raise ValueError(f"Env '{env_name}' not found. Available envs: {ALL_ENVS}")
#
# File /bigdata/rhome/ajcd2020/research/mujoco/Transformable-Leg-Wheel-Robot/.venv/lib64/python3.11/site-packages/mujoco_playground/_src/dm_control_suite/__init__.py:157, in load(env_name, config, config_overrides)
#     153   raise ValueError(
#     154       f"Env '{env_name}' not found. Available envs: {_cfgs.keys()}"
#     155   )
#     156 config = config or get_default_config(env_name)
# --> 157 return _envs[env_name](config=config, config_overrides=config_overrides)
#
# File /bigdata/rhome/ajcd2020/research/mujoco/Transformable-Leg-Wheel-Robot/packages/twmr/src/twmr/twmr.py:54, in TransformableWheelMobileRobot.__init__(self, config, config_overrides)
#      51 super().__init__(config, config_overrides)
#      53 self._xml_path = _XML_PATH.as_posix()
# ---> 54 model_xml = _XML_PATH.read_text()
#      55 self._model_assets = common.get_assets()
#      56 self._mj_model: MjModel = MjModel.from_xml_string(model_xml, self._model_assets)
#
# File /usr/lib64/python3.11/pathlib.py:1058, in Path.read_text(self, encoding, errors)
#    1054 """
#    1055 Open the file in text mode, read it, and close the file.
#    1056 """
#    1057 encoding = io.text_encoding(encoding)
# -> 1058 with self.open(mode='r', encoding=encoding, errors=errors) as f:
#    1059     return f.read()
#
# File /usr/lib64/python3.11/pathlib.py:1044, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1042 if "b" not in mode:
#    1043     encoding = io.text_encoding(encoding)
# -> 1044 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/bigdata/rhome/ajcd2020/research/mujoco/Transformable-Leg-Wheel-Robot/packages/twmr/src/twmr/assets/wheeled_mobile_robot.xml'

# %%
env_cfg = registry.get_default_config("TransformableWheelMobileRobot")
env_cfg

# %%
jit_reset = jax.jit(env.reset)
jit_step = jax.jit(env.step)

# %%
state = jit_reset(jax.random.PRNGKey(0))
rollout = [state]

f = 0.5
for i in range(env_cfg.episode_length):
    action = []
    for j in range(env.action_size):
        action.append(jp.sin(state.data.time * 2 * jp.pi * f + j * 2 * jp.pi / env.action_size))
    action = jp.array(action)
    state = jit_step(state, action)
    rollout.append(state)

frames = env.render(rollout)
media.show_video(frames, fps=1.0 / env.dt)
